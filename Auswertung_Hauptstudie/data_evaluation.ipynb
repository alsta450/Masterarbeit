# %%
import pandas as pd
import numpy as np
import openpyxl
from bioinfokit.analys import stat
from scipy import stats as st

# %%
df = pd.read_excel(r"data_masterstudie_filtered.xlsx")

# %%
df
# Out:
#      Unnamed: 0  FS01_CP  FS01  SD03  SD05  SD11 SD11_10  SD14 SD14_08  SD16  \
# 0             1        0     1     4     2     8     NaN     3     NaN     7
# 1             2        0     2    11     2     8     NaN     6     NaN    11
# 2             3        0     3     3     1     7     NaN     3     NaN     4
# 3             5        1     3     3     1     8     NaN     3     NaN     5
# 4             6        1     2     5     2     8     NaN     4     NaN     6
# ..          ...      ...   ...   ...   ...   ...     ...   ...     ...   ...
# 113         138       44     1    -9    -9     8     NaN     3     NaN     5
# 114         139       45     2     3     1     7     NaN     3     NaN     4
# 115         140       45     3     3     1     8     NaN     3     NaN     1
# 116         141       45     1     4     1     8     NaN     3     NaN     4
# 117         142       46     3     3     1     7     NaN     3     NaN     4
#
# ...

# %%
res = stat()

# %%
a = df.loc[df["FS01"] == 2,'AN02_01']
b=df.loc[df["FS01"] == 2,'AN02_02']

# %%
a = df.loc[df["FS01"] == 2,'AN03_01']
b=df.loc[df["FS01"] == 2,'AN03_02']

# %%
a = df.loc[df["FS01"] == 1,'AN04_01']
b=df.loc[df["FS01"] == 1,'AN04_02']

# %%
np.average(a)
# Out:
# 55.32432432432432

# %%
np.average(b)
# Out:
# 43.432432432432435

# %%
st.ttest_ind(a=a,b=b,equal_var=True)
# Out:
# Ttest_indResult(statistic=1.32974618819911, pvalue=0.18779939424100048)
